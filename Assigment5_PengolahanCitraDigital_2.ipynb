# %%
#Muhammad Haidar Matin
#20220040152
#TI22T

# %%
import cv2
import numpy as np

# %%
#Gambar ori 4k
img_ori = cv2.imread('lutfy.jpg')
print('Original dimensions :', img_ori.shape)
# Out:
# Original dimensions : (128, 128, 3)

# %%
#merubah ukuran 4k
width=3840
height=2160
dim = (width,height)

# %%
img_new = cv2.resize(img_ori, dim, interpolation = cv2.INTER_AREA )
print('Resize Dimesions :', img_new.shape)
# Out:
# Resize Dimesions : (2160, 3840, 3)

# %%
#Gambar ori
from google.colab.patches import cv2_imshow
cv2_imshow(img_ori)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
#Gambar 4k
from google.colab.patches import cv2_imshow
cv2_imshow(img_new)
# Out:
# <PIL.Image.Image image mode=RGB size=3840x2160>
